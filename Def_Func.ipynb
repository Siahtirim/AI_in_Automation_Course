# %%
#simpel
def printer():
    print("Hello World we need your help")

# %%
printer()
printer()
# Out:
# Hello World we need your help
# Hello World we need your help

# %%
#def with parameters
def adder(a,b):
    print("Final add is ", a+b)

# %%
adder(10, 20)
adder(30, 40)
# Out:
# Final add is  30
# Final add is  70

# %%
x1 = int(input("Enter first number: "))
y1 = int(input("Enter second number: "))
ali = adder(x1,y1)
print(ali)
# Out:
# Final add is  300
# None

# %%
# def with return
def mul(aa,bb):
    return aa * bb

# %%
ali = mul(10,300)
print(ali)
# Out:
# 3000
