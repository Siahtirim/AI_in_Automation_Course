# %%
#Range
ali = range(0, 10, 3)   # 0, 3
print(ali[1])
# Out:
# 3

# %%
#List
poweren = [10, 22 , -3, "Ali", 22, [-1000, -2000]]
land = [ -100, -200]
shop = poweren.index(-3,0,-1)
print(shop)
print(poweren)
# Out:
# 2
# [10, 22, -3, 'Ali', 22, [-1000, -2000]]

# %%
#Tupel
Iran = ('Tehran', 'Shiraz', 100, 200)
Country = Iran.index(100)
print(Country)
print(type(Iran))
# Out:
# 2
# <class 'tuple'>

# %%
#dic
content = {'name':"Reza", 'family': "Siahtiri", 'Phone': "09121001010"}
temp= content['name'] = "Rezaeii"
print(temp)
print(content)
# Out:
# Rezaeii
# {'name': 'Rezaeii', 'family': 'Siahtiri', 'Phone': '09121001010'}

# %%
x = "WOrd"
y = "None"
tempx = dict.fromkeys(x, y)
print(tempx)
# Out:
# {'W': 'None', 'O': 'None', 'r': 'None', 'd': 'None'}

# %%
#Set
asghar = {22 , 33 , 33, -10}

print(asghar)
# Out:
# {33, 22, -10}
